# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ### Markdown heading

# %% [markdown]
# # Markup List

# %% [markdown]
# Ordered list:
#
# 1. Step 1
#     2. Step 1B
# 3. Step 3

# %% [markdown]
# Task list
#
# - [x] Learn Jupyter Notebooks
#     - [x] Writing
#     - [x] Modes
#     - [x] Other Considerations
# - [ ] Change the world

# %% [markdown]
# Image import

# %%
# Import necessary libraries
from fastai.vision import * 
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
from google.colab import files
from io import BytesIO
from PIL import Image

uploaded = files.upload()
# Out:
#      <input type="file" id="files-917ec9ed-df50-4212-a432-54d6ab206479" name="files[]" multiple disabled />
#      <output id="result-917ec9ed-df50-4212-a432-54d6ab206479">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1a-Boxplot.png to 1a-Boxplot (1).png

# %%
Image.open(BytesIO(uploaded['1a-Boxplot.png']))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2560x1600 at 0x7F1CB0E90390>
